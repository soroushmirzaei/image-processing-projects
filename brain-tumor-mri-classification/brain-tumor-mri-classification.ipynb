# %% [markdown]
# <a href="https://colab.research.google.com/github/soroushmirzaei/convolutional-neural-networks-projects/blob/main/brain-tumor-mri-classification/brain-tumor-mri-classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import requirements libraries
import os
import zipfile

#import mathematics statics libraries
import numpy as np
import pandas as pd

#import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

#import machine learning deep learning libraries
import tensorflow as tf
from tensorflow import keras

# %%
#make kaggle json file
kaggle_json = {
    "username":"kaggle-api-token-username",
    "key":"kaggle-api-token-key"
}
pd.Series(kaggle_json).to_json('kaggle.json')

#install kaggle libraries
# !pip install -q kaggle

#setup kaggle libraries
# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
#download kaggle dataset
# !kaggle datasets download masoudnickparvar/brain-tumor-mri-dataset
# Out:
# Downloading brain-tumor-mri-dataset.zip to /content
# 100% 149M/149M [00:01<00:00, 96.2MB/s]
# 100% 149M/149M [00:01<00:00, 84.0MB/s]

# %%
#unzip file
def unzip(file_name, type_file = 'zip'):
    cur_dir = os.getcwd()
    file_path = os.path.join(cur_dir, f'{file_name}.{type_file}')
    file = zipfile.ZipFile(file_path)
    file.extractall(os.path.join(cur_dir, file_name))
    file.close()

# %%
unzip('brain-tumor-mri-dataset')

# %%
#remove file with zero size
def remove_file_zero(dir_path):
    for root, dirs, files in os.walk(dir_path):
        for file in files:
            if os.path.getsize(os.path.join(root, file)) == 0:
                os.remove(os.path.join(root, file))

# %%
remove_file_zero('/content/brain-tumor-mri-dataset')

# %%
#romove other file type
def remove_type(dir_path):
    for root, dirs, files in os.walk(dir_path):
        for file in files:
            if file.split('.')[-1] not in ['jpg', 'jpeg', 'bmp', 'png', 'gif']:
                os.remove(os.path.join(root, file))

# %%
remove_type('/content/brain-tumor-mri-dataset/Training')
remove_type('/content/brain-tumor-mri-dataset/Testing')

# %%
#rename file in label num format
def rename_file(dir_path):
    for label in os.listdir(dir_path):
        num = 0
        for file in os.scandir(os.path.join(dir_path, label)):
            file_name = file.name
            ext = file_name.split('.')[1]
            num = num + 1
            os.rename(file.path, os.path.join(dir_path, label, f'{label} {num}.{ext}'))

# %%
rename_file('/content/brain-tumor-mri-dataset/Training')
rename_file('/content/brain-tumor-mri-dataset/Testing')

# %%
#capsfold file names
def caps_file(dir_path):
    for root, dirs, files in os.walk(dir_path):
        for dir in dirs:
            os.rename(os.path.join(root,dir), os.path.join(root,dir.title()))
    for root, dirs, files in os.walk(dir_path):
        for file in files:
            os.rename(os.path.join(root,file), os.path.join(root,file.title()))

# %%
caps_file('/content/brain-tumor-mri-dataset/Training')
caps_file('/content/brain-tumor-mri-dataset/Testing')

# %%
#define training validation set
Height = 150
Width = 150

train_gen = keras.preprocessing.image.ImageDataGenerator(rescale = 1/255)
train_data = train_gen.flow_from_directory('/content/brain-tumor-mri-dataset/Training',
                                           target_size = (Height, Width), batch_size = 32,
                                           color_mode = 'rgb', class_mode = 'sparse', seed = 0)

valid_gen = keras.preprocessing.image.ImageDataGenerator(rescale = 1/255)
valid_data = valid_gen.flow_from_directory('/content/brain-tumor-mri-dataset/Testing',
                                         target_size = (Height, Width), batch_size = 32,
                                         color_mode = 'rgb', class_mode = 'sparse', seed = 0)
# Out:
# Found 3637 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
#define pretrained model
pretrained_model = keras.applications.InceptionV3(input_shape = (Height, Width, 3),
                                                  include_top = False)

for layer in pretrained_model.layers:
    layer.trainable = False

output_pre = pretrained_model.output

# %%
#define custom pretrained model
out_layer = pretrained_model.get_layer('mixed8')
output_custom_pre = out_layer.output

# %%
#create model function
def create_model(#convolution layer configuration
                 conv_layers_num, conv_filters, conv_kernel_size, flatten_dropout_ratio, 
                 #dense layer configuration
                 dense_layers_num, dense_units, dense_dropout_ratio,
                 #output layer configuration
                 out_dropout_ratio, out_units = train_data.num_classes,
                 #activations configuration
                 conv_activation = 'relu', dense_activation = 'relu', out_activation = 'softmax',

                 #input shape
                 inp_shape = (Height, Width, 3),

                 #compiling Configuration
                 compile_optimizer = 'adam', compile_loss ='sparse_categorical_crossentropy' ,
                 compile_metric = ['accuracy'],
                 
                 #pretrained_model configuration
                 flatten_input = None, pretrained_input = False,
                 
                 #convolution layers
                 conv_base = True, batch_norm_conv = True,
                 #flatten layer
                 flatten_layer = True, flatten_dropout_out = True,
                 #dense layers
                 dense_head = True,  batch_norm_dense = True, dropout_dense = True,
                 #output layer
                 batch_norm_out = True, dropout_out = True
                 ):

    #define input layer
    input = keras.Input(inp_shape)
    out = input

    #define convolution layers
    if conv_base:
        for i in range(conv_layers_num):
            if batch_norm_conv:
                out = keras.layers.BatchNormalization()(out)
            out = keras.layers.Conv2D(filters = conv_filters[i],
                                      kernel_size = conv_kernel_size[i], activation = conv_activation,
                                      kernel_initializer = keras.initializers.GlorotNormal())(out)
            out = keras.layers.MaxPool2D(pool_size = 2)(out)

    #convert two dims to one dim
    if flatten_layer:
        try:
            out = keras.layers.Flatten()(flatten_input)
        except:
            out = keras.layers.Flatten()(out)

    if flatten_dropout_out:
        out = keras.layers.Dropout(flatten_dropout_ratio)(out)

    #define dense layers
    if dense_head:
        for i in range(dense_layers_num):
            if batch_norm_dense:
                out = keras.layers.BatchNormalization()(out)
            out = keras.layers.Dense(units = dense_units[i], activation = dense_activation,
                                     kernel_initializer = keras.initializers.HeNormal())(out)
            if dropout_dense:
                out = keras.layers.Dropout(dense_dropout_ratio[i])(out)

    #define output layers
    if batch_norm_out:
        out = keras.layers.BatchNormalization()(out)
    if dropout_out:
        out = keras.layers.Dropout(out_dropout_ratio)(out)
    output = keras.layers.Dense(units = out_units, activation = out_activation)(out)

    if pretrained_input:
        input = pretrained_model.input

    model = keras.models.Model(input, output)

    #define model compile
    model.compile(optimizer = compile_optimizer,
                  loss = compile_loss,
                  metrics = compile_metric)

    return model

# %%
#define custom callbacks
class callback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = None):
        self.model.save('/content/brain-tumor-mri-classification-model.h5')

# %%
#create model
model = create_model(#convolution layer configuration
                     conv_layers_num = int(3), conv_filters = list([16,32,32]), conv_kernel_size = list([3,3,3]),
                     flatten_dropout_ratio = float(0.3), 
                     #dense layer configuration
                     dense_layers_num = int(2), dense_units = list([128,128]), dense_dropout_ratio = list([0.3,0.3]), 
                     #output layer configuration
                     out_dropout_ratio = float(0.3), out_units = train_data.num_classes,
                     #activations configuration
                     conv_activation = 'relu', dense_activation = 'relu', out_activation = 'softmax',
                     
                     #input shape
                     inp_shape = (Height, Width, 3),
                     
                     #compiling Configuration
                     compile_optimizer = 'adam', compile_loss = 'sparse_categorical_crossentropy' ,
                     compile_metric = ['accuracy'],
                     
                     #pretrained_model configuration
                     flatten_input = output_custom_pre, pretrained_input = True,

                     #convolution layers
                     conv_base = True, batch_norm_conv = True,
                     #flatten layer
                     flatten_layer = True, flatten_dropout_out = True,                  
                     #dense layers
                     dense_head = True,  batch_norm_dense = True, dropout_dense = True,
                     #output layer
                     batch_norm_out = True, dropout_out = True
                    )

# %%
#print model summary
model.summary(120)
# Out:
# Model: "model_6"
# ________________________________________________________________________________________________________________________
#  Layer (type)                          Output Shape               Param #       Connected to
# ========================================================================================================================
#  input_8 (InputLayer)                  [(None, 150, 150, 3)]      0             []
#
#  conv2d_112 (Conv2D)                   (None, 74, 74, 32)         864           ['input_8[0][0]']
#
#  batch_normalization_130 (BatchNormali  (None, 74, 74, 32)        96            ['conv2d_112[0][0]']
#  zation)
#
#  activation_94 (Activation)            (None, 74, 74, 32)         0             ['batch_normalization_130[0][0]']
#
#  conv2d_113 (Conv2D)                   (None, 72, 72, 32)         9216          ['activation_94[0][0]']
#
#  batch_normalization_131 (BatchNormali  (None, 72, 72, 32)        96            ['conv2d_113[0][0]']
#  zation)
#
#  activation_95 (Activation)            (None, 72, 72, 32)         0             ['batch_normalization_131[0][0]']
#
#  conv2d_114 (Conv2D)                   (None, 72, 72, 64)         18432         ['activation_95[0][0]']
#
#  batch_normalization_132 (BatchNormali  (None, 72, 72, 64)        192           ['conv2d_114[0][0]']
#  zation)
#
#  activation_96 (Activation)            (None, 72, 72, 64)         0             ['batch_normalization_132[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D)       (None, 35, 35, 64)         0             ['activation_96[0][0]']
#
#  conv2d_115 (Conv2D)                   (None, 35, 35, 80)         5120          ['max_pooling2d_22[0][0]']
#
#  batch_normalization_133 (BatchNormali  (None, 35, 35, 80)        240           ['conv2d_115[0][0]']
#  zation)
#
#  activation_97 (Activation)            (None, 35, 35, 80)         0             ['batch_normalization_133[0][0]']
#
#  conv2d_116 (Conv2D)                   (None, 33, 33, 192)        138240        ['activation_97[0][0]']
#
#  batch_normalization_134 (BatchNormali  (None, 33, 33, 192)       576           ['conv2d_116[0][0]']
#  zation)
#
#  activation_98 (Activation)            (None, 33, 33, 192)        0             ['batch_normalization_134[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D)       (None, 16, 16, 192)        0             ['activation_98[0][0]']
#
#  conv2d_120 (Conv2D)                   (None, 16, 16, 64)         12288         ['max_pooling2d_23[0][0]']
#
#  batch_normalization_138 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_120[0][0]']
#  zation)
#
#  activation_102 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_138[0][0]']
#
#  conv2d_118 (Conv2D)                   (None, 16, 16, 48)         9216          ['max_pooling2d_23[0][0]']
#
#  conv2d_121 (Conv2D)                   (None, 16, 16, 96)         55296         ['activation_102[0][0]']
#
#  batch_normalization_136 (BatchNormali  (None, 16, 16, 48)        144           ['conv2d_118[0][0]']
#  zation)
#
#  batch_normalization_139 (BatchNormali  (None, 16, 16, 96)        288           ['conv2d_121[0][0]']
#  zation)
#
#  activation_100 (Activation)           (None, 16, 16, 48)         0             ['batch_normalization_136[0][0]']
#
#  activation_103 (Activation)           (None, 16, 16, 96)         0             ['batch_normalization_139[0][0]']
#
#  average_pooling2d_9 (AveragePooling2D  (None, 16, 16, 192)       0             ['max_pooling2d_23[0][0]']
#  )
#
#  conv2d_117 (Conv2D)                   (None, 16, 16, 64)         12288         ['max_pooling2d_23[0][0]']
#
#  conv2d_119 (Conv2D)                   (None, 16, 16, 64)         76800         ['activation_100[0][0]']
#
#  conv2d_122 (Conv2D)                   (None, 16, 16, 96)         82944         ['activation_103[0][0]']
#
#  conv2d_123 (Conv2D)                   (None, 16, 16, 32)         6144          ['average_pooling2d_9[0][0]']
#
#  batch_normalization_135 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_117[0][0]']
#  zation)
#
#  batch_normalization_137 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_119[0][0]']
#  zation)
#
#  batch_normalization_140 (BatchNormali  (None, 16, 16, 96)        288           ['conv2d_122[0][0]']
#  zation)
#
#  batch_normalization_141 (BatchNormali  (None, 16, 16, 32)        96            ['conv2d_123[0][0]']
#  zation)
#
#  activation_99 (Activation)            (None, 16, 16, 64)         0             ['batch_normalization_135[0][0]']
#
#  activation_101 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_137[0][0]']
#
#  activation_104 (Activation)           (None, 16, 16, 96)         0             ['batch_normalization_140[0][0]']
#
#  activation_105 (Activation)           (None, 16, 16, 32)         0             ['batch_normalization_141[0][0]']
#
#  mixed0 (Concatenate)                  (None, 16, 16, 256)        0             ['activation_99[0][0]',
#                                                                                  'activation_101[0][0]',
#                                                                                  'activation_104[0][0]',
#                                                                                  'activation_105[0][0]']
#
#  conv2d_127 (Conv2D)                   (None, 16, 16, 64)         16384         ['mixed0[0][0]']
#
#  batch_normalization_145 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_127[0][0]']
#  zation)
#
#  activation_109 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_145[0][0]']
#
#  conv2d_125 (Conv2D)                   (None, 16, 16, 48)         12288         ['mixed0[0][0]']
#
#  conv2d_128 (Conv2D)                   (None, 16, 16, 96)         55296         ['activation_109[0][0]']
#
#  batch_normalization_143 (BatchNormali  (None, 16, 16, 48)        144           ['conv2d_125[0][0]']
#  zation)
#
#  batch_normalization_146 (BatchNormali  (None, 16, 16, 96)        288           ['conv2d_128[0][0]']
#  zation)
#
#  activation_107 (Activation)           (None, 16, 16, 48)         0             ['batch_normalization_143[0][0]']
#
#  activation_110 (Activation)           (None, 16, 16, 96)         0             ['batch_normalization_146[0][0]']
#
#  average_pooling2d_10 (AveragePooling2  (None, 16, 16, 256)       0             ['mixed0[0][0]']
#  D)
#
#  conv2d_124 (Conv2D)                   (None, 16, 16, 64)         16384         ['mixed0[0][0]']
#
#  conv2d_126 (Conv2D)                   (None, 16, 16, 64)         76800         ['activation_107[0][0]']
#
#  conv2d_129 (Conv2D)                   (None, 16, 16, 96)         82944         ['activation_110[0][0]']
#
#  conv2d_130 (Conv2D)                   (None, 16, 16, 64)         16384         ['average_pooling2d_10[0][0]']
#
#  batch_normalization_142 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_124[0][0]']
#  zation)
#
#  batch_normalization_144 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_126[0][0]']
#  zation)
#
#  batch_normalization_147 (BatchNormali  (None, 16, 16, 96)        288           ['conv2d_129[0][0]']
#  zation)
#
#  batch_normalization_148 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_130[0][0]']
#  zation)
#
#  activation_106 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_142[0][0]']
#
#  activation_108 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_144[0][0]']
#
#  activation_111 (Activation)           (None, 16, 16, 96)         0             ['batch_normalization_147[0][0]']
#
#  activation_112 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_148[0][0]']
#
#  mixed1 (Concatenate)                  (None, 16, 16, 288)        0             ['activation_106[0][0]',
#                                                                                  'activation_108[0][0]',
#                                                                                  'activation_111[0][0]',
#                                                                                  'activation_112[0][0]']
#
#  conv2d_134 (Conv2D)                   (None, 16, 16, 64)         18432         ['mixed1[0][0]']
#
#  batch_normalization_152 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_134[0][0]']
#  zation)
#
#  activation_116 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_152[0][0]']
#
#  conv2d_132 (Conv2D)                   (None, 16, 16, 48)         13824         ['mixed1[0][0]']
#
#  conv2d_135 (Conv2D)                   (None, 16, 16, 96)         55296         ['activation_116[0][0]']
#
#  batch_normalization_150 (BatchNormali  (None, 16, 16, 48)        144           ['conv2d_132[0][0]']
#  zation)
#
#  batch_normalization_153 (BatchNormali  (None, 16, 16, 96)        288           ['conv2d_135[0][0]']
#  zation)
#
#  activation_114 (Activation)           (None, 16, 16, 48)         0             ['batch_normalization_150[0][0]']
#
#  activation_117 (Activation)           (None, 16, 16, 96)         0             ['batch_normalization_153[0][0]']
#
#  average_pooling2d_11 (AveragePooling2  (None, 16, 16, 288)       0             ['mixed1[0][0]']
#  D)
#
#  conv2d_131 (Conv2D)                   (None, 16, 16, 64)         18432         ['mixed1[0][0]']
#
#  conv2d_133 (Conv2D)                   (None, 16, 16, 64)         76800         ['activation_114[0][0]']
#
#  conv2d_136 (Conv2D)                   (None, 16, 16, 96)         82944         ['activation_117[0][0]']
#
#  conv2d_137 (Conv2D)                   (None, 16, 16, 64)         18432         ['average_pooling2d_11[0][0]']
#
#  batch_normalization_149 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_131[0][0]']
#  zation)
#
#  batch_normalization_151 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_133[0][0]']
#  zation)
#
#  batch_normalization_154 (BatchNormali  (None, 16, 16, 96)        288           ['conv2d_136[0][0]']
#  zation)
#
#  batch_normalization_155 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_137[0][0]']
#  zation)
#
#  activation_113 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_149[0][0]']
#
#  activation_115 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_151[0][0]']
#
#  activation_118 (Activation)           (None, 16, 16, 96)         0             ['batch_normalization_154[0][0]']
#
#  activation_119 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_155[0][0]']
#
#  mixed2 (Concatenate)                  (None, 16, 16, 288)        0             ['activation_113[0][0]',
#                                                                                  'activation_115[0][0]',
#                                                                                  'activation_118[0][0]',
#                                                                                  'activation_119[0][0]']
#
#  conv2d_139 (Conv2D)                   (None, 16, 16, 64)         18432         ['mixed2[0][0]']
#
#  batch_normalization_157 (BatchNormali  (None, 16, 16, 64)        192           ['conv2d_139[0][0]']
#  zation)
#
#  activation_121 (Activation)           (None, 16, 16, 64)         0             ['batch_normalization_157[0][0]']
#
#  conv2d_140 (Conv2D)                   (None, 16, 16, 96)         55296         ['activation_121[0][0]']
#
#  batch_normalization_158 (BatchNormali  (None, 16, 16, 96)        288           ['conv2d_140[0][0]']
#  zation)
#
#  activation_122 (Activation)           (None, 16, 16, 96)         0             ['batch_normalization_158[0][0]']
#
#  conv2d_138 (Conv2D)                   (None, 7, 7, 384)          995328        ['mixed2[0][0]']
#
#  conv2d_141 (Conv2D)                   (None, 7, 7, 96)           82944         ['activation_122[0][0]']
#
#  batch_normalization_156 (BatchNormali  (None, 7, 7, 384)         1152          ['conv2d_138[0][0]']
#  zation)
#
#  batch_normalization_159 (BatchNormali  (None, 7, 7, 96)          288           ['conv2d_141[0][0]']
#  zation)
#
#  activation_120 (Activation)           (None, 7, 7, 384)          0             ['batch_normalization_156[0][0]']
#
#  activation_123 (Activation)           (None, 7, 7, 96)           0             ['batch_normalization_159[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D)       (None, 7, 7, 288)          0             ['mixed2[0][0]']
#
#  mixed3 (Concatenate)                  (None, 7, 7, 768)          0             ['activation_120[0][0]',
#                                                                                  'activation_123[0][0]',
#                                                                                  'max_pooling2d_24[0][0]']
#
#  conv2d_146 (Conv2D)                   (None, 7, 7, 128)          98304         ['mixed3[0][0]']
#
#  batch_normalization_164 (BatchNormali  (None, 7, 7, 128)         384           ['conv2d_146[0][0]']
#  zation)
#
#  activation_128 (Activation)           (None, 7, 7, 128)          0             ['batch_normalization_164[0][0]']
#
#  conv2d_147 (Conv2D)                   (None, 7, 7, 128)          114688        ['activation_128[0][0]']
#
#  batch_normalization_165 (BatchNormali  (None, 7, 7, 128)         384           ['conv2d_147[0][0]']
#  zation)
#
#  activation_129 (Activation)           (None, 7, 7, 128)          0             ['batch_normalization_165[0][0]']
#
#  conv2d_143 (Conv2D)                   (None, 7, 7, 128)          98304         ['mixed3[0][0]']
#
#  conv2d_148 (Conv2D)                   (None, 7, 7, 128)          114688        ['activation_129[0][0]']
#
#  batch_normalization_161 (BatchNormali  (None, 7, 7, 128)         384           ['conv2d_143[0][0]']
#  zation)
#
#  batch_normalization_166 (BatchNormali  (None, 7, 7, 128)         384           ['conv2d_148[0][0]']
#  zation)
#
#  activation_125 (Activation)           (None, 7, 7, 128)          0             ['batch_normalization_161[0][0]']
#
#  activation_130 (Activation)           (None, 7, 7, 128)          0             ['batch_normalization_166[0][0]']
#
#  conv2d_144 (Conv2D)                   (None, 7, 7, 128)          114688        ['activation_125[0][0]']
#
#  conv2d_149 (Conv2D)                   (None, 7, 7, 128)          114688        ['activation_130[0][0]']
#
#  batch_normalization_162 (BatchNormali  (None, 7, 7, 128)         384           ['conv2d_144[0][0]']
#  zation)
#
#  batch_normalization_167 (BatchNormali  (None, 7, 7, 128)         384           ['conv2d_149[0][0]']
#  zation)
#
#  activation_126 (Activation)           (None, 7, 7, 128)          0             ['batch_normalization_162[0][0]']
#
#  activation_131 (Activation)           (None, 7, 7, 128)          0             ['batch_normalization_167[0][0]']
#
#  average_pooling2d_12 (AveragePooling2  (None, 7, 7, 768)         0             ['mixed3[0][0]']
#  D)
#
#  conv2d_142 (Conv2D)                   (None, 7, 7, 192)          147456        ['mixed3[0][0]']
#
#  conv2d_145 (Conv2D)                   (None, 7, 7, 192)          172032        ['activation_126[0][0]']
#
#  conv2d_150 (Conv2D)                   (None, 7, 7, 192)          172032        ['activation_131[0][0]']
#
#  conv2d_151 (Conv2D)                   (None, 7, 7, 192)          147456        ['average_pooling2d_12[0][0]']
#
#  batch_normalization_160 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_142[0][0]']
#  zation)
#
#  batch_normalization_163 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_145[0][0]']
#  zation)
#
#  batch_normalization_168 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_150[0][0]']
#  zation)
#
#  batch_normalization_169 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_151[0][0]']
#  zation)
#
#  activation_124 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_160[0][0]']
#
#  activation_127 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_163[0][0]']
#
#  activation_132 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_168[0][0]']
#
#  activation_133 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_169[0][0]']
#
#  mixed4 (Concatenate)                  (None, 7, 7, 768)          0             ['activation_124[0][0]',
#                                                                                  'activation_127[0][0]',
#                                                                                  'activation_132[0][0]',
#                                                                                  'activation_133[0][0]']
#
#  conv2d_156 (Conv2D)                   (None, 7, 7, 160)          122880        ['mixed4[0][0]']
#
#  batch_normalization_174 (BatchNormali  (None, 7, 7, 160)         480           ['conv2d_156[0][0]']
#  zation)
#
#  activation_138 (Activation)           (None, 7, 7, 160)          0             ['batch_normalization_174[0][0]']
#
#  conv2d_157 (Conv2D)                   (None, 7, 7, 160)          179200        ['activation_138[0][0]']
#
#  batch_normalization_175 (BatchNormali  (None, 7, 7, 160)         480           ['conv2d_157[0][0]']
#  zation)
#
#  activation_139 (Activation)           (None, 7, 7, 160)          0             ['batch_normalization_175[0][0]']
#
#  conv2d_153 (Conv2D)                   (None, 7, 7, 160)          122880        ['mixed4[0][0]']
#
#  conv2d_158 (Conv2D)                   (None, 7, 7, 160)          179200        ['activation_139[0][0]']
#
#  batch_normalization_171 (BatchNormali  (None, 7, 7, 160)         480           ['conv2d_153[0][0]']
#  zation)
#
#  batch_normalization_176 (BatchNormali  (None, 7, 7, 160)         480           ['conv2d_158[0][0]']
#  zation)
#
#  activation_135 (Activation)           (None, 7, 7, 160)          0             ['batch_normalization_171[0][0]']
#
#  activation_140 (Activation)           (None, 7, 7, 160)          0             ['batch_normalization_176[0][0]']
#
#  conv2d_154 (Conv2D)                   (None, 7, 7, 160)          179200        ['activation_135[0][0]']
#
#  conv2d_159 (Conv2D)                   (None, 7, 7, 160)          179200        ['activation_140[0][0]']
#
#  batch_normalization_172 (BatchNormali  (None, 7, 7, 160)         480           ['conv2d_154[0][0]']
#  zation)
#
#  batch_normalization_177 (BatchNormali  (None, 7, 7, 160)         480           ['conv2d_159[0][0]']
#  zation)
#
#  activation_136 (Activation)           (None, 7, 7, 160)          0             ['batch_normalization_172[0][0]']
#
#  activation_141 (Activation)           (None, 7, 7, 160)          0             ['batch_normalization_177[0][0]']
#
#  average_pooling2d_13 (AveragePooling2  (None, 7, 7, 768)         0             ['mixed4[0][0]']
#  D)
#
#  conv2d_152 (Conv2D)                   (None, 7, 7, 192)          147456        ['mixed4[0][0]']
#
#  conv2d_155 (Conv2D)                   (None, 7, 7, 192)          215040        ['activation_136[0][0]']
#
#  conv2d_160 (Conv2D)                   (None, 7, 7, 192)          215040        ['activation_141[0][0]']
#
#  conv2d_161 (Conv2D)                   (None, 7, 7, 192)          147456        ['average_pooling2d_13[0][0]']
#
#  batch_normalization_170 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_152[0][0]']
#  zation)
#
#  batch_normalization_173 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_155[0][0]']
#  zation)
#
#  batch_normalization_178 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_160[0][0]']
#  zation)
#
#  batch_normalization_179 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_161[0][0]']
#  zation)
#
#  activation_134 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_170[0][0]']
#
#  activation_137 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_173[0][0]']
#
# ...
#  zation)
#
#  activation_155 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_191[0][0]']
#
#  activation_160 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_196[0][0]']
#
#  conv2d_174 (Conv2D)                   (None, 7, 7, 192)          258048        ['activation_155[0][0]']
#
#  conv2d_179 (Conv2D)                   (None, 7, 7, 192)          258048        ['activation_160[0][0]']
#
#  batch_normalization_192 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_174[0][0]']
#  zation)
#
#  batch_normalization_197 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_179[0][0]']
#  zation)
#
#  activation_156 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_192[0][0]']
#
#  activation_161 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_197[0][0]']
#
#  average_pooling2d_15 (AveragePooling2  (None, 7, 7, 768)         0             ['mixed6[0][0]']
#  D)
#
#  conv2d_172 (Conv2D)                   (None, 7, 7, 192)          147456        ['mixed6[0][0]']
#
#  conv2d_175 (Conv2D)                   (None, 7, 7, 192)          258048        ['activation_156[0][0]']
#
#  conv2d_180 (Conv2D)                   (None, 7, 7, 192)          258048        ['activation_161[0][0]']
#
#  conv2d_181 (Conv2D)                   (None, 7, 7, 192)          147456        ['average_pooling2d_15[0][0]']
#
#  batch_normalization_190 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_172[0][0]']
#  zation)
#
#  batch_normalization_193 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_175[0][0]']
#  zation)
#
#  batch_normalization_198 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_180[0][0]']
#  zation)
#
#  batch_normalization_199 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_181[0][0]']
#  zation)
#
#  activation_154 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_190[0][0]']
#
#  activation_157 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_193[0][0]']
#
#  activation_162 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_198[0][0]']
#
#  activation_163 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_199[0][0]']
#
#  mixed7 (Concatenate)                  (None, 7, 7, 768)          0             ['activation_154[0][0]',
#                                                                                  'activation_157[0][0]',
#                                                                                  'activation_162[0][0]',
#                                                                                  'activation_163[0][0]']
#
#  conv2d_184 (Conv2D)                   (None, 7, 7, 192)          147456        ['mixed7[0][0]']
#
#  batch_normalization_202 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_184[0][0]']
#  zation)
#
#  activation_166 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_202[0][0]']
#
#  conv2d_185 (Conv2D)                   (None, 7, 7, 192)          258048        ['activation_166[0][0]']
#
#  batch_normalization_203 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_185[0][0]']
#  zation)
#
#  activation_167 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_203[0][0]']
#
#  conv2d_182 (Conv2D)                   (None, 7, 7, 192)          147456        ['mixed7[0][0]']
#
#  conv2d_186 (Conv2D)                   (None, 7, 7, 192)          258048        ['activation_167[0][0]']
#
#  batch_normalization_200 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_182[0][0]']
#  zation)
#
#  batch_normalization_204 (BatchNormali  (None, 7, 7, 192)         576           ['conv2d_186[0][0]']
#  zation)
#
#  activation_164 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_200[0][0]']
#
#  activation_168 (Activation)           (None, 7, 7, 192)          0             ['batch_normalization_204[0][0]']
#
#  conv2d_183 (Conv2D)                   (None, 3, 3, 320)          552960        ['activation_164[0][0]']
#
#  conv2d_187 (Conv2D)                   (None, 3, 3, 192)          331776        ['activation_168[0][0]']
#
#  batch_normalization_201 (BatchNormali  (None, 3, 3, 320)         960           ['conv2d_183[0][0]']
#  zation)
#
#  batch_normalization_205 (BatchNormali  (None, 3, 3, 192)         576           ['conv2d_187[0][0]']
#  zation)
#
#  activation_165 (Activation)           (None, 3, 3, 320)          0             ['batch_normalization_201[0][0]']
#
#  activation_169 (Activation)           (None, 3, 3, 192)          0             ['batch_normalization_205[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D)       (None, 3, 3, 768)          0             ['mixed7[0][0]']
#
#  mixed8 (Concatenate)                  (None, 3, 3, 1280)         0             ['activation_165[0][0]',
#                                                                                  'activation_169[0][0]',
#                                                                                  'max_pooling2d_25[0][0]']
#
#  flatten_10 (Flatten)                  (None, 11520)              0             ['mixed8[0][0]']
#
#  dropout_24 (Dropout)                  (None, 11520)              0             ['flatten_10[0][0]']
#
#  batch_normalization_227 (BatchNormali  (None, 11520)             46080         ['dropout_24[0][0]']
#  zation)
#
#  dense_18 (Dense)                      (None, 128)                1474688       ['batch_normalization_227[0][0]']
#
#  dropout_25 (Dropout)                  (None, 128)                0             ['dense_18[0][0]']
#
#  batch_normalization_228 (BatchNormali  (None, 128)               512           ['dropout_25[0][0]']
#  zation)
#
#  dense_19 (Dense)                      (None, 128)                16512         ['batch_normalization_228[0][0]']
#
#  dropout_26 (Dropout)                  (None, 128)                0             ['dense_19[0][0]']
#
#  batch_normalization_229 (BatchNormali  (None, 128)               512           ['dropout_26[0][0]']
#  zation)
#
#  dropout_27 (Dropout)                  (None, 128)                0             ['batch_normalization_229[0][0]']
#
#  dense_20 (Dense)                      (None, 4)                  516           ['dropout_27[0][0]']
#
# ========================================================================================================================
# Total params: 12,213,668
# Trainable params: 1,515,268
# Non-trainable params: 10,698,400
# ________________________________________________________________________________________________________________________

# %%
#fit model for training
history = model.fit(train_data, validation_data = valid_data, epochs = 100,
                    callbacks = [keras.callbacks.EarlyStopping(patience = 5, restore_best_weights = True,
                                                               monitor = 'val_accuracy'),
                                 keras.callbacks.CSVLogger('Log.csv'), callback(), 
                                 keras.callbacks.ReduceLROnPlateau('val_accuracy', patience = 3,
                                                                   factor = 0.1)],
                    )
# Out:
# Epoch 1/100
# 114/114 [==============================] - 259s 2s/step - loss: 0.6772 - accuracy: 0.7608 - val_loss: 0.3340 - val_accuracy: 0.8787 - lr: 0.0010
# Epoch 2/100
# 114/114 [==============================] - 187s 2s/step - loss: 0.3306 - accuracy: 0.8837 - val_loss: 0.2348 - val_accuracy: 0.9146 - lr: 0.0010
# Epoch 3/100
# 114/114 [==============================] - 185s 2s/step - loss: 0.2235 - accuracy: 0.9233 - val_loss: 0.1890 - val_accuracy: 0.9321 - lr: 0.0010
# Epoch 4/100
# 114/114 [==============================] - 188s 2s/step - loss: 0.1638 - accuracy: 0.9412 - val_loss: 0.1596 - val_accuracy: 0.9413 - lr: 0.0010
# Epoch 5/100
# 114/114 [==============================] - 186s 2s/step - loss: 0.1209 - accuracy: 0.9574 - val_loss: 0.1495 - val_accuracy: 0.9451 - lr: 0.0010
# Epoch 6/100
# 114/114 [==============================] - 185s 2s/step - loss: 0.1059 - accuracy: 0.9656 - val_loss: 0.1566 - val_accuracy: 0.9420 - lr: 0.0010
# Epoch 7/100
# 114/114 [==============================] - 187s 2s/step - loss: 0.0975 - accuracy: 0.9667 - val_loss: 0.1864 - val_accuracy: 0.9489 - lr: 0.0010
# Epoch 8/100
# 114/114 [==============================] - 186s 2s/step - loss: 0.0961 - accuracy: 0.9687 - val_loss: 0.1508 - val_accuracy: 0.9489 - lr: 0.0010
# Epoch 9/100
# 114/114 [==============================] - 187s 2s/step - loss: 0.0780 - accuracy: 0.9700 - val_loss: 0.1690 - val_accuracy: 0.9474 - lr: 0.0010
# Epoch 10/100
# 114/114 [==============================] - 187s 2s/step - loss: 0.0785 - accuracy: 0.9775 - val_loss: 0.1472 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 11/100
# 114/114 [==============================] - 185s 2s/step - loss: 0.0705 - accuracy: 0.9775 - val_loss: 0.1875 - val_accuracy: 0.9397 - lr: 0.0010
# Epoch 12/100
# 114/114 [==============================] - 190s 2s/step - loss: 0.0567 - accuracy: 0.9805 - val_loss: 0.1549 - val_accuracy: 0.9519 - lr: 0.0010
# Epoch 13/100
# 114/114 [==============================] - 187s 2s/step - loss: 0.0568 - accuracy: 0.9810 - val_loss: 0.1615 - val_accuracy: 0.9527 - lr: 0.0010
# Epoch 14/100
# 114/114 [==============================] - 186s 2s/step - loss: 0.0633 - accuracy: 0.9805 - val_loss: 0.1845 - val_accuracy: 0.9474 - lr: 0.0010
# Epoch 15/100
# 114/114 [==============================] - 186s 2s/step - loss: 0.0543 - accuracy: 0.9832 - val_loss: 0.1894 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 16/100
# 114/114 [==============================] - 187s 2s/step - loss: 0.0530 - accuracy: 0.9832 - val_loss: 0.1557 - val_accuracy: 0.9535 - lr: 0.0010
# Epoch 17/100
# 114/114 [==============================] - 187s 2s/step - loss: 0.0397 - accuracy: 0.9879 - val_loss: 0.1397 - val_accuracy: 0.9603 - lr: 0.0010
# Epoch 18/100
# 114/114 [==============================] - 186s 2s/step - loss: 0.0435 - accuracy: 0.9868 - val_loss: 0.1513 - val_accuracy: 0.9603 - lr: 0.0010
# Epoch 19/100
# 114/114 [==============================] - 187s 2s/step - loss: 0.0417 - accuracy: 0.9824 - val_loss: 0.1599 - val_accuracy: 0.9558 - lr: 0.0010
# Epoch 20/100
# 114/114 [==============================] - 186s 2s/step - loss: 0.0396 - accuracy: 0.9863 - val_loss: 0.2542 - val_accuracy: 0.9458 - lr: 0.0010
# Epoch 21/100
# 114/114 [==============================] - 186s 2s/step - loss: 0.0459 - accuracy: 0.9832 - val_loss: 0.1780 - val_accuracy: 0.9565 - lr: 1.0000e-04
# Epoch 22/100
# 114/114 [==============================] - 186s 2s/step - loss: 0.0277 - accuracy: 0.9904 - val_loss: 0.1669 - val_accuracy: 0.9588 - lr: 1.0000e-04

# %%
#plot history and logger
pd.DataFrame(model.history.history)[['loss', 'val_loss']].plot(figsize = (9, 6), linewidth = 3)
plt.grid(linestyle = '--', linewidth = 2)
plt.show()

# %%
#plot history and logger
pd.DataFrame(model.history.history)[['accuracy', 'val_accuracy']].plot(figsize = (9, 6), linewidth = 3)
plt.grid(linestyle = '--', linewidth = 2)
plt.ylim(0,1)
plt.show()

# %%
#model evaluation
train_set_eval = model.evaluate(train_data, verbose = 0)
valid_set_eval = model.evaluate(valid_data, verbose = 0)

print(f'Training Set Evaluation:\n\tLoss: {round(train_set_eval[0],4)}\tAccuracy: {100*round(train_set_eval[1],4)}%')
print(f'Validation Set Evaluation:\n\tLoss: {round(valid_set_eval[0],4)}\tAccuracy: {100*round(valid_set_eval[1],4)}%')
# Out:
# Training Set Evaluation:
# 	Loss: 0.0015	Accuracy: 100.0%
# Validation Set Evaluation:
# 	Loss: 0.1397	Accuracy: 96.03%

# %%
#make list of images for random prediction
def image_file(dir_path):
    image_list = list()
    for root, dirs, files in os.walk(dir_path):
        for file in files:
            image_list.append(os.path.join(root, file))
    return image_list

# %%
#draw random image
img = np.random.choice(image_file('/content/brain-tumor-mri-dataset/Testing'))
image = img
img = keras.preprocessing.image.load_img(img, target_size = (Height, Width),
                                         color_mode = 'rgb')
img = keras.preprocessing.image.img_to_array(img)

img = img/255
plt.axis('off')
plt.imshow(img)
plt.title(image.split('/')[-1])
plt.show()

# %%
#prediction for random image
img = np.expand_dims(img, 0)
pd.DataFrame(model.predict(img), columns = train_data.class_indices)
# Out:
#      Glioma    Meningioma       Notumor  Pituitary
# 0  0.999995  4.487241e-07  7.151577e-09   0.000004

# %%
#save model
model.save('/content/brain-tumor-mri-classification-model.h5')
